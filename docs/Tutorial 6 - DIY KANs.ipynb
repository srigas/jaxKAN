# %% [markdown]
# # Tutorial 6 - DIY KANs

# %% [markdown]
# In all previous tutorials we've been using the `KAN` class from `jaxkan.KAN` in order to define a network. However, if one requires more fine-grained access over the network's constituents, they may define their own custom KAN class by using one (or more) KAN Layers from the `jaxkan.layers` module.

# %%
import os
import sys

# Workaround to import jaxKAN
project_root = os.path.abspath("..")
sys.path.append(project_root)

from jaxkan.layers.ChebyLayer import ChebyLayer
from jaxkan.layers.FourierLayer import FourierLayer

import jax
import jax.numpy as jnp

from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

from flax import nnx
import optax

from typing import List

import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## Custom KAN Class

# %% [markdown]
# In general, the custom KAN class should inherit from `nnx.Module` and contain an `__init__` and `__call__` method. Apart from these, there are no other pre-requisites. For example, if one does not intend to perform grid updates, there is no need to define a `update_grids` method.
#
# As an example, we will create a custom KAN class to perform the same function fitting task as in the first tutorial, this time using a mix of Chebychev Layers, Fourier Layers and additional transformations in between.

# %%
class CustomKAN(nnx.Module):
    def __init__(self, cheby_layers, fourier_layers, add_bias = True, rngs = nnx.Rngs(42)):
        self.add_bias = add_bias

        self.CLayers = [
                ChebyLayer(
                    n_in = cheby_layers[i],
                    n_out = cheby_layers[i + 1],
                    k = 5,
                    rngs = rngs
                )
                for i in range(len(cheby_layers)-1)
            ]

        self.FLayers = [
                FourierLayer(
                    n_in = fourier_layers[i],
                    n_out = fourier_layers[i + 1],
                    k = 10,
                    rngs = rngs
                )
                for i in range(len(fourier_layers)-1)
            ]

        if self.add_bias:
            dims = cheby_layers[1:] + fourier_layers[1:]
            self.biases = [
                nnx.Param(jnp.zeros((dim,))) for dim in dims
            ]

    def __call__(self, x):
        bidx = 0
        for _, layer in enumerate(self.CLayers):
            x = layer(x)

            if self.add_bias:
                x += self.biases[bidx].value
                bidx += 1

        # Apply a GELU transformation
        x = nnx.gelu(x, approximate=True)

        for _, layer in enumerate(self.FLayers):
            x = layer(x)

            if self.add_bias:
                x += self.biases[bidx].value
                bidx += 1

        return x

# %% [markdown]
# ## Data Generation & Preprocessing

# %% [markdown]
# Again, we create data for the function $f(x, y) = x^2 + 2\exp(y)$.

# %%
def f(x,y):
    return x**2 + 2*jnp.exp(y)

def generate_data(minval=-1, maxval=1, num_samples=1000, seed=42):
    key = jax.random.PRNGKey(seed)
    x_key, y_key = jax.random.split(key)

    x1 = jax.random.uniform(x_key, shape=(num_samples,), minval=minval, maxval=maxval)
    x2 = jax.random.uniform(y_key, shape=(num_samples,), minval=minval, maxval=maxval)

    y = f(x1, x2).reshape(-1, 1)
    X = jnp.stack([x1, x2], axis=1)
    
    return X, y

# %%
seed = 42

X, y = generate_data(minval=-1, maxval=1, num_samples=1000, seed=seed)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=seed)

# %% [markdown]
# ## Training

# %% [markdown]
# Let's now define an instance of the CustomKAN class, with 2 Chebychev Layers and 2 Fourier Layers.

# %%
n_hidden = 5
cheby_layers = [X_train.shape[1], n_hidden, n_hidden]
fourier_layers = [n_hidden, n_hidden, y_train.shape[1]]

# Sanity check for dimensions matching
assert cheby_layers[-1] == fourier_layers[0]

model = CustomKAN(cheby_layers, fourier_layers, True, nnx.Rngs(42))

# %%
opt_type = optax.adam(learning_rate=0.001)

optimizer = nnx.Optimizer(model, opt_type)

# %%
# Define train loop
@nnx.jit
def train_step(model, optimizer, X_train, y_train):

    def loss_fn(model):
        residual = model(X_train) - y_train
        loss = jnp.mean((residual)**2)

        return loss
    
    loss, grads = nnx.value_and_grad(loss_fn)(model)
    optimizer.update(grads)
    
    return loss

# %%
# Initialize train_losses
num_epochs = 2000
train_losses = jnp.zeros((num_epochs,))

for epoch in range(num_epochs):
    # Calculate the loss
    loss = train_step(model, optimizer, X_train, y_train)
    
    # Append the loss
    train_losses = train_losses.at[epoch].set(loss)

# %% [markdown]
# ## Evaluation

# %%
plt.figure(figsize=(7, 4))

plt.plot(np.array(train_losses), label='Train Loss', marker='o', color='#25599c', markersize=1)

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training Loss Over Epochs')
plt.yscale('log')

plt.legend()
plt.grid(True, which='both', linestyle='--', linewidth=0.5) 

plt.show()

# %%
y_pred = model(X_test)
mse = mean_squared_error(y_test, y_pred)

print(f"The MSE of the fit is {mse:.5f}")
# Out:
# The MSE of the fit is 0.00045

# %%
plt.figure(figsize=(7, 4))
plt.scatter(y_test, y_pred, alpha=0.7, color='#a3630f', marker='x', label='Predicted vs Actual')
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], color='#25599c', linestyle='--', label='Perfect Fit')
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.title('Model Predictions vs Ground Truth')
plt.legend()
plt.grid(alpha=0.3)
plt.show()
